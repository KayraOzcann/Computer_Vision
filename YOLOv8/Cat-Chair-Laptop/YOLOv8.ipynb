# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import ultralytics
ultralytics.checks()

# %%
# !yolo task=detect mode=train model=/content/drive/MyDrive/yolov8(..).pt imgsz=640 data=/content/drive/MyDrive/..../data_custom.yaml epochs=(..) batch=(..) project=/content/drive/MyDrive/.../training_results

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/...../training_results/..../weights/best.pt conf=0.5 source=/content/drive/MyDrive/..../Test/ project=/content/drive/MyDrive/...../Prediction save=True
